# %% [markdown]
# # SLIM-GSGP LIBRARY TESTING + EXERCISES

# %% [markdown]
# This notebook is dedicated to testing the SLIM library and working on selected exercises looking to better understand it's organization.

# %% [markdown]
# ## **For all 3 algorithms (GP, GSGP, SLIM):**

# %% [markdown]
# ### 1. Add a constant set and use it during the evolution process, show the final individual to make sure it has constants

# %% [markdown]
# The current library only has a defined function set, not considering the possibility of constant values being used during the evolution of programs. Adding a constant set opens space to a more complete evolution of the individuals in the population.

# %% [markdown]
# #### **GP**:

# %% [markdown]
# ##### Libraries:

# %%
from slim_gsgp.main_gp import gp  # import the slim_gsgp library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split  # import the train-test split function

# %% [markdown]
# ##### Dataset:

# %%
# Load the PPB dataset
X, y = load_ppb(X_y=True)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)

# %% [markdown]
# ##### MODEL:

# %% [markdown]
# **Baseline with no constant set:**

# %%
# Apply the GP algorithm
final_tree_f =  gp(X_train=X_train, y_train=y_train,
                X_test=X_val, y_test=y_val,
                dataset_name='ppb', pop_size=100, n_iter=100)
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   40.56873321533203   |   39.31814956665039      |   0.061817169189453125 |      3           |
# |     ppb                 |       1      |   36.83185958862305   |   38.91961669921875      |   0.010618925094604492 |      3           |
# |     ppb                 |       2      |   34.91804504394531   |   36.0217399597168       |   0.010009050369262695 |      3           |
# |     ppb                 |       3      |   30.349258422851562  |   33.08704376220703      |   0.007938861846923828 |      3           |
# |     ppb                 |       4      |   30.349258422851562  |   33.08704376220703      |   0.00789499282836914  |      3           |
# |     ppb                 |       5      |   29.83997344970703   |   32.37567138671875      |   0.007553815841674805 |      9           |
# |     ppb                 |       6      |   29.83997344970703   |   32.37567138671875      |   0.0069980621337890625|      9           |
# |     ppb                 |       7      |   29.08783721923828   |   32.219627380371094     |   0.008290767669677734 |      9           |
# |     ppb                 |       8      |   29.08783721923828   |   32.219627380371094     |   0.0089111328125      |      9           |
# |     ppb                 |       9      |   29.08783721923828   |   32.219627380371094     |   0.00877523422241211  |      9           |
# |     ppb                 |       10     |   29.08783721923828   |   32.219627380371094     |   0.008910894393920898 |      9           |
# |     ppb                 |       11     |   29.08783721923828   |   32.219627380371094     |   0.009816169738769531 |      9           |
# |     ppb                 |       12     |   29.08783721923828   |   32.219627380371094     |   0.009725332260131836 |      9           |
# |     ppb                 |       13     |   29.08783721923828   |   32.219627380371094     |   0.010672807693481445 |      9           |
# |     ppb                 |       14     |   29.08783721923828   |   32.219627380371094     |   0.010113000869750977 |      9           |
# |     ppb                 |       15     |   29.08783721923828   |   32.219627380371094     |   0.010678768157958984 |      9           |
# |     ppb                 |       48     |   27.48518943786621   |   31.65882110595703      |   0.046437978744506836 |      51          |
# |     ppb                 |       49     |   27.48518943786621   |   31.65882110595703      |   0.0430142879486084   |      51          |
# |     ppb                 |       50     |   27.48518943786621   |   31.65882110595703      |   0.050251007080078125 |      51          |
# |     ppb                 |       51     |   27.3508243560791    |   31.463531494140625     |   0.043772220611572266 |      49          |
# |     ppb                 |       52     |   27.3508243560791    |   31.463531494140625     |   0.0504000186920166   |      49          |
# |     ppb                 |       53     |   27.3508243560791    |   31.463531494140625     |   0.13086819648742676  |      49          |
# |     ppb                 |       54     |   27.268877029418945  |   31.25107192993164      |   0.05320096015930176  |      53          |
# |     ppb                 |       55     |   27.268877029418945  |   31.25107192993164      |   0.05955314636230469  |      53          |
# |     ppb                 |       56     |   27.268877029418945  |   31.25107192993164      |   0.059556007385253906 |      53          |
# |     ppb                 |       57     |   27.1675968170166    |   29.944988250732422     |   0.06843280792236328  |      65          |
# |     ppb                 |       58     |   27.1675968170166    |   29.944988250732422     |   0.06574010848999023  |      65          |
# |     ppb                 |       59     |   27.1675968170166    |   29.944988250732422     |   0.05854678153991699  |      65          |
# |     ppb                 |       60     |   27.112112045288086  |   29.695186614990234     |   0.05865597724914551  |      59          |
# |     ppb                 |       61     |   27.112112045288086  |   29.695186614990234     |   0.05925917625427246  |      59          |
# |     ppb                 |       62     |   27.112112045288086  |   29.695186614990234     |   0.05517005920410156  |      59          |
# |     ppb                 |       63     |   27.112112045288086  |   29.695186614990234     |   0.05412602424621582  |      59          |
# |     ppb                 |       64     |   27.112112045288086  |   29.695186614990234     |   0.06445002555847168  |      59          |
# |     ppb                 |       65     |   27.093820571899414  |   30.088214874267578     |   0.05823683738708496  |      73          |
# |     ppb                 |       66     |   27.067415237426758  |   30.35491180419922      |   0.07046318054199219  |      64          |
# |     ppb                 |       67     |   27.016101837158203  |   29.964759826660156     |   0.06912899017333984  |      73          |
# |     ppb                 |       68     |   26.987892150878906  |   30.04897689819336      |   0.07119512557983398  |      73          |
# |     ppb                 |       69     |   26.937942504882812  |   30.29585075378418      |   0.07208681106567383  |      76          |
# |     ppb                 |       70     |   26.937942504882812  |   30.29585075378418      |   0.0785379409790039   |      76          |
# |     ppb                 |       71     |   26.90155792236328   |   30.433916091918945     |   0.08509206771850586  |      76          |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Apply the GP algorithm
# ----> 2 final_tree_f =  gp(X_train=X_train, y_train=y_train,
#       3                 X_test=X_val, y_test=y_val,
#       4                 dataset_name='ppb', pop_size=100, n_iter=100)
#
# File ~/Desktop/Master Thesis/CODE_SLIM/slim_gsgp/slim_gsgp/main_gp.py:243, in gp(X_train, y_train, X_test, y_test, dataset_name, pop_size, n_iter, p_xo, elitism, n_elites, max_depth, init_depth, log_path, seed, log_level, verbose, minimization, fitness_function, initializer, n_jobs, prob_const, tree_functions, tree_constants, tournament_size, test_elite)
#     238 # ================================
#     239 #       Running the Algorithm
#     240 # ================================
#     242 optimizer = GP(pi_init=gp_pi_init, **gp_parameters)
# --> 243 optimizer.solve(
#     244     X_train=X_train,
#     245     X_test=X_test,
#     246     y_train=y_train,
#     247     y_test=y_test,
#     248     curr_dataset=dataset_name,
#     249     **gp_solve_parameters
#     250 )
#     252 log_settings(
#     253     path=log_path[:-4] + "_settings.csv",
#     254     settings_dict=[gp_solve_parameters,
#    (...)
#     258     unique_run_id=unique_run_id,
#     259 )
#     261 return optimizer.elite
#
# File ~/Desktop/Master Thesis/CODE_SLIM/slim_gsgp/slim_gsgp/algorithms/GP/gp.py:202, in GP.solve(self, X_train, X_test, y_train, y_test, curr_dataset, n_iter, elitism, log, verbose, test_elite, log_path, run_info, max_depth, ffunction, n_elites, depth_calculator, n_jobs)
#     199 # EVOLUTIONARY PROCESS
#     200 for it in range(1, n_iter + 1):
#     201     # getting the offspring population
# --> 202     offs_pop, start = self.evolve_population(
#     203         population,
#     204         ffunction,
#     205         max_depth,
#     206         depth_calculator,
#     207         elitism,
#     208         X_train,
#     209         y_train,
#     210         n_jobs=n_jobs
#     211     )
#     212     # replacing the population with the offspring population (P = P')
#     213     population = offs_pop
#
# File ~/Desktop/Master Thesis/CODE_SLIM/slim_gsgp/slim_gsgp/algorithms/GP/gp.py:339, in GP.evolve_population(self, population, ffunction, max_depth, depth_calculator, elitism, X_train, y_train, n_jobs)
#     336         offspring = [offs1]
#     338     # adding the offspring as instances of Tree to the offspring population
# --> 339     offs_pop.extend([Tree(child) for child in offspring])
#     341 # making sure the offspring population is of the same size as the population
#     342 if len(offs_pop) > population.size:
#
# File ~/Desktop/Master Thesis/CODE_SLIM/slim_gsgp/slim_gsgp/algorithms/GP/representations/tree.py:74, in Tree.__init__(self, repr_)
#      72 self.fitness = None
#      73 self.test_fitness = None
# ---> 74 self.node_count = len(list(flatten(self.repr_)))
#
# File ~/Desktop/Master Thesis/CODE_SLIM/slim_gsgp/slim_gsgp/algorithms/GP/representations/tree_utils.py:69, in flatten(data)
#      67 if isinstance(data, tuple):
#      68     for x in data:
# ---> 69         yield from flatten(x)
#      70 else:
#      71     yield data
#
# File ~/Desktop/Master Thesis/CODE_SLIM/slim_gsgp/slim_gsgp/algorithms/GP/representations/tree_utils.py:69, in flatten(data)
#      67 if isinstance(data, tuple):
#      68     for x in data:
# ---> 69         yield from flatten(x)
#      70 else:
#      71     yield data
#
#     [... skipping similar frames: flatten at line 69 (7 times)]
#
# File ~/Desktop/Master Thesis/CODE_SLIM/slim_gsgp/slim_gsgp/algorithms/GP/representations/tree_utils.py:69, in flatten(data)
#      67 if isinstance(data, tuple):
#      68     for x in data:
# ---> 69         yield from flatten(x)
#      70 else:
#      71     yield data
#
# KeyboardInterrupt:

# %% [markdown]
# Getting representation:

# %%
# Show the best individual structure at the last generation
final_tree_f.print_tree_representation()
# Out:
# add(
#   add(
#     x534
#     add(
#       x457
#       add(
#         x457
#         add(
#           x524
#           add(
#             x457
#             add(
#               x15
#               divide(
#                 x605
#                 add(
#                   x407
#                   add(
#                     x79
#                     add(
#                       x457
#                       add(
#                         x524
#                         add(
#                           x407
#                           subtract(
#                             x379
#                             x100
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   add(
#     x457
#     add(
#       x524
#       add(
#         x457
#         add(
#           x15
#           divide(
#             x605
#             add(
#               x407
#               add(
#                 x79
#                 add(
#                   x457
#                   add(
#                     x524
#                     add(
#                       x407
#                       add(
#                         x457
#                         divide(
#                           x605
#                           divide(
#                             x359
#                             subtract(
#                               x195
#                               add(
#                                 x524
#                                 x100
#                               )
#                             )
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# Getting RMSE to check performance:

# %%
# Get the prediction of the best individual on the test set
predictions = final_tree_f.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# 28.124900817871094

# %% [markdown]
# **Model with constant set:**

# %% [markdown]
# After exploring the code, a few things are noted:
# - The main implementation of GP (*main_gp.py*) already includes the possibility of a constant set, as it makes it possible to add a constant set to the search space / dictionary (pi_init).
# - All we need to actually do is get to the **gp_config.py** and change the configuration of the search space (*gp_pi_init*) to have a probability different from 0 (it was set to 0, so no constants were added).
#
# Testing for **p_c = 0.3**:
# - Simply changing the probability of being constant gives back an error: *"mul(): argument 'input' (position 1) must be Tensor, not dict"*, needed to correct **apply_tree from tree.py** and change the **CONSTANTS** dictionary from **gp_config.py** (*abs(): argument 'input' (position 1) must be Tensor, not function*).

# %%
final_tree_c = gp(X_train=X_train, y_train=y_train,
                X_test=X_val, y_test=y_val,
                dataset_name='ppb', pop_size=100, n_iter=100, p_xo = 0)
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   43.867095947265625  |   46.88303756713867      |   0.07063102722167969  |      3           |
# |     ppb                 |       1      |   43.867095947265625  |   46.88303756713867      |   0.015156984329223633 |      3           |
# |     ppb                 |       2      |   43.867095947265625  |   46.88303756713867      |   0.016156911849975586 |      3           |
# |     ppb                 |       3      |   43.867095947265625  |   46.88303756713867      |   0.016138076782226562 |      3           |
# |     ppb                 |       4      |   43.867095947265625  |   46.88303756713867      |   0.015645980834960938 |      3           |
# |     ppb                 |       5      |   33.88179397583008   |   35.796810150146484     |   0.017338037490844727 |      7           |
# |     ppb                 |       6      |   33.88179397583008   |   35.796810150146484     |   0.018418073654174805 |      7           |
# |     ppb                 |       7      |   33.88179397583008   |   35.796810150146484     |   0.016813039779663086 |      7           |
# |     ppb                 |       8      |   33.88179397583008   |   35.796810150146484     |   0.01733088493347168  |      7           |
# |     ppb                 |       9      |   31.717498779296875  |   34.24504089355469      |   0.017288923263549805 |      7           |
# |     ppb                 |       10     |   31.45806312561035   |   34.41872024536133      |   0.017108917236328125 |      13          |
# |     ppb                 |       11     |   30.07716178894043   |   32.012290954589844     |   0.01687908172607422  |      11          |
# |     ppb                 |       12     |   30.07716178894043   |   32.012290954589844     |   0.017132043838500977 |      11          |
# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions_c)))
# Out:
# 30.261333465576172

# %% [markdown]
# #### **GSGP**:

# %%
from slim_gsgp.main_gsgp import gsgp  # import the slim library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split  # import the train-test split function
from slim_gsgp.utils.utils import generate_random_uniform  # import the mutation step function

# %%
# Load the PPB dataset
X, y = load_ppb(X_y=True)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)

# %%
# Apply the Standard GSGP algorithm
final_tree = gsgp(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', pop_size=100, n_iter=100,
                  reconstruct=True, ms_lower=0, ms_upper=1)


# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   57.22980880737305   |   60.118648529052734     |   0.1320788860321045   |      3           |
# |     ppb                 |       1      |   57.012939453125     |   59.90546417236328      |   0.030529022216796875 |      9           |
# |     ppb                 |       2      |   57.012939453125     |   59.90546417236328      |   0.030605792999267578 |      9           |
# |     ppb                 |       3      |   56.786285400390625  |   59.68736267089844      |   0.03196072578430176  |      15          |
# |     ppb                 |       4      |   56.68245315551758   |   59.5860481262207       |   0.028074979782104492 |      21          |
# |     ppb                 |       5      |   56.06733322143555   |   58.988372802734375     |   0.029671907424926758 |      27          |
# |     ppb                 |       6      |   55.86701583862305   |   58.76530075073242      |   0.028457164764404297 |      33          |
# |     ppb                 |       7      |   55.502357482910156  |   58.42348098754883      |   0.02989816665649414  |      39          |
# |     ppb                 |       8      |   55.239234924316406  |   58.152992248535156     |   0.03166913986206055  |      45          |
# |     ppb                 |       9      |   54.80342102050781   |   57.7288932800293       |   0.028765201568603516 |      51          |
# |     ppb                 |       10     |   54.708988189697266  |   57.5573844909668       |   0.0322268009185791   |      59          |
# |     ppb                 |       11     |   54.45937728881836   |   57.40095520019531      |   0.031404972076416016 |      57          |
# |     ppb                 |       12     |   54.04957580566406   |   57.00214767456055      |   0.03206968307495117  |      63          |
# |     ppb                 |       13     |   53.95264434814453   |   56.907344818115234     |   0.03017902374267578  |      69          |
# |     ppb                 |       14     |   53.757911682128906  |   56.608394622802734     |   0.03285789489746094  |      77          |
# |     ppb                 |       15     |   53.464454650878906  |   56.4351806640625       |   0.031063079833984375 |      81          |
# |     ppb                 |       16     |   53.203575134277344  |   56.09865188598633      |   0.029217004776000977 |      89          |
# |     ppb                 |       17     |   52.99372482299805   |   55.973045349121094     |   0.030290842056274414 |      87          |
# |     ppb                 |       18     |   52.64656448364258   |   55.64015197753906      |   0.03137922286987305  |      93          |
# |     ppb                 |       82     |   37.931678771972656  |   41.389984130859375     |   0.028645038604736328 |      443         |
# |     ppb                 |       83     |   37.60837936401367   |   41.0407829284668       |   0.029651880264282227 |      461         |
# |     ppb                 |       84     |   37.516109466552734  |   40.932525634765625     |   0.029590845108032227 |      467         |
# |     ppb                 |       85     |   37.295169830322266  |   40.7387580871582       |   0.02819204330444336  |      467         |
# |     ppb                 |       86     |   37.295169830322266  |   40.7387580871582       |   0.028903961181640625 |      467         |
# |     ppb                 |       87     |   37.04168701171875   |   40.5279426574707       |   0.028608083724975586 |      479         |
# |     ppb                 |       88     |   36.820457458496094  |   40.25792694091797      |   0.028628826141357422 |      485         |
# |     ppb                 |       89     |   36.81374740600586   |   40.250396728515625     |   0.029382944107055664 |      491         |
# |     ppb                 |       90     |   36.59601974487305   |   40.03914260864258      |   0.030398845672607422 |      497         |
# |     ppb                 |       91     |   36.394290924072266  |   39.84478759765625      |   0.02975606918334961  |      503         |
# |     ppb                 |       92     |   36.258419036865234  |   39.7132453918457       |   0.0290830135345459   |      503         |
# |     ppb                 |       93     |   35.971187591552734  |   39.43468475341797      |   0.02834296226501465  |      509         |
# |     ppb                 |       94     |   35.88404083251953   |   39.35161590576172      |   0.028338909149169922 |      509         |
# |     ppb                 |       95     |   35.84566116333008   |   39.234893798828125     |   0.027826786041259766 |      521         |
# |     ppb                 |       96     |   35.614078521728516  |   39.09074401855469      |   0.029855012893676758 |      521         |
# |     ppb                 |       97     |   35.57982635498047   |   39.04893493652344      |   0.0314030647277832   |      521         |
# |     ppb                 |       98     |   35.27167510986328   |   38.76980972290039      |   0.028655052185058594 |      533         |
# |     ppb                 |       99     |   35.24334716796875   |   38.744956970214844     |   0.029675960540771484 |      539         |
# |     ppb                 |       100    |   35.182193756103516  |   38.67305374145508      |   0.028239011764526367 |      545         |
# 35.838199615478516

# %% [markdown]
# With GSGP, we don't check tree representation as individuals usually get too big to be interpretable.

# %% [markdown]
# #### **SLIM**:

# %% [markdown]
# With SLIM, we already have the porblem of different dimension, must fix it with new version of individual.

# %%
from slim_gsgp.main_slim import slim  # import the slim library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split, show_individual  # import the train-test split function
from slim_gsgp.utils.utils import generate_random_uniform  # import the mutation step function

# %%
X, y = load_ppb(X_y=True)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)

# %%
# Apply the SLIM GSGP algorithm
final_tree = slim(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', slim_version='SLIM+SIG2', pop_size=100, n_iter=100,
                  ms_lower=0, ms_upper=1, p_inflate=0.5)

# Show the best individual structure at the last generation
print(show_individual(final_tree, operator='sum'))

# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# |     ppb                 |       92     |   39.630714416503906  |   42.3962287902832       |   0.011332035064697266 |      124         |
# |     ppb                 |       93     |   39.630714416503906  |   42.3962287902832       |   0.011687994003295898 |      124         |
# |     ppb                 |       94     |   39.630714416503906  |   42.3962287902832       |   0.010634899139404297 |      124         |
# |     ppb                 |       95     |   39.418304443359375  |   42.17953872680664      |   0.013123750686645508 |      124         |
# |     ppb                 |       96     |   39.418304443359375  |   42.17953872680664      |   0.00888204574584961  |      124         |
# |     ppb                 |       97     |   39.418304443359375  |   42.17953872680664      |   0.00876617431640625  |      124         |
# |     ppb                 |       98     |   39.418304443359375  |   42.17953872680664      |   0.011494159698486328 |      124         |
# |     ppb                 |       99     |   39.418304443359375  |   42.17953872680664      |   0.007513284683227539 |      124         |
# |     ppb                 |       100    |   39.418304443359375  |   42.17953872680664      |   0.0124359130859375   |      124         |
# (np.str_('multiply'), np.str_('x56'), np.str_('x481')) + f((np.str_('divide'), np.str_('x522'), np.str_('x372')) - (np.str_('multiply'), np.str_('x331'), np.str_('x335'))) + f((np.str_('multiply'), np.str_('x266'), np.str_('x451')) - (np.str_('multiply'), np.str_('constant__1.0'), np.str_('x308'))) + f((np.str_('divide'), np.str_('x532'), np.str_('x528')) - (np.str_('subtract'), np.str_('constant__1.0'), np.str_('x547'))) + f((np.str_('add'), np.str_('constant_5.0'), np.str_('x582')) - (np.str_('subtract'), np.str_('constant__1.0'), np.str_('x432'))) + f((np.str_('add'), np.str_('x191'), np.str_('x454')) - (np.str_('subtract'), np.str_('constant_2.0'), np.str_('x391'))) + f((np.str_('add'), np.str_('x198'), np.str_('x27')) - (np.str_('divide'), np.str_('x574'), np.str_('x329'))) + f((np.str_('add'), np.str_('x332'), np.str_('x373')) - (np.str_('subtract'), np.str_('x576'), np.str_('constant_5.0'))) + f((np.str_('add'), np.str_('constant_4.0'), np.str_('x281')) - (np.str_('divide'), np.str_('constant_4.0'), np.str_('constant__1.0'))) + f((np.str_('subtract'), np.str_('x392'), np.str_('x282')) - (np.str_('subtract'), np.str_('x375'), np.str_('x273'))) + f((np.str_('divide'), np.str_('x369'), np.str_('x146')) - (np.str_('divide'), np.str_('x409'), np.str_('constant__1.0'))) + f((np.str_('subtract'), np.str_('constant_4.0'), np.str_('x622')) - (np.str_('subtract'), np.str_('x573'), np.str_('x125')))
# 39.848846435546875

# %% [markdown]
# -----

# %% [markdown]
# ### 2. Change the functions set by adding a new function with arity 1 (ex. cos) and a new function with arity 2 (ex.mean)

# %% [markdown]
# For this question, we simply need to change the function set in the **xx_config.py** file.

# %% [markdown]
# #### **GP**

# %%
from slim_gsgp.main_gp import gp  # import the slim library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split  # import the train-test split function

# %%
# Load the PPB dataset
X, y = load_ppb(X_y=True)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test
# |     ppb                 |       91     |   25.723209381103516  |   30.689403533935547     |   0.06278681755065918  |      71          |
# |     ppb                 |       92     |   25.602081298828125  |   30.799713134765625     |   0.08944010734558105  |      72          |
# |     ppb                 |       93     |   25.602081298828125  |   30.799713134765625     |   0.053502798080444336 |      72          |
# |     ppb                 |       94     |   25.602081298828125  |   30.799713134765625     |   0.05336403846740723  |      72          |
# |     ppb                 |       95     |   25.443492889404297  |   30.70613670349121      |   0.06897091865539551  |      94          |
# |     ppb                 |       96     |   25.443492889404297  |   30.70613670349121      |   0.06408405303955078  |      94          |
# |     ppb                 |       97     |   25.37779426574707   |   30.776378631591797     |   0.07054400444030762  |      96          |
# |     ppb                 |       98     |   25.37779426574707   |   30.776378631591797     |   0.07037806510925293  |      96          |
# |     ppb                 |       99     |   25.37779426574707   |   30.776378631591797     |   0.0679171085357666   |      96          |
# |     ppb                 |       100    |   25.37779426574707   |   30.776378631591797     |   0.07626104354858398  |      96          |

# %%
final_tree_f.print_tree_representation()
# Out:
# mean(
#   add(
#     add(
#       x201
#       add(
#         x201
#         multiply(
#           x103
#           cosine(
#             add(
#               x518
#               add(
#                 x201
#                 add(
#                   x201
#                   cosine(
#                     subtract(
#                       x390
#                       cosine(
#                         subtract(
#                           x390
#                           divide(
#                             x578
#                             x332
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#     add(
#       x201
#       add(
#         x201
#         cosine(
#           add(
#             x518
#             add(
#               x201
#               add(
#                 x201
#                 add(
#                   x201
#                   add(
#                     x201
#                     cosine(
#                       subtract(
#                         x390
#                         cosine(
#                           subtract(
#                             x390
#                             divide(
#                               x578
#                               x332
#                             )
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   multiply(
#     x485
#     add(
#       x91
#       add(
#         add(
#           x201
#           add(
#             x201
#             multiply(
#               x103
#               cosine(
#                 add(
#                   x518
#                   add(
#                     x201
#                     add(
#                       x201
#                       cosine(
#                         subtract(
#                           x390
#                           cosine(
#                             subtract(
#                               x390
#                               divide(
#                                 x578
#                                 x332
#                               )
#                             )
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#         add(
#           x201
#           add(
#             x201
#             cosine(
#               add(
#                 x518
#                 add(
#                   x201
#                   add(
#                     x201
#                     cosine(
#                       divide(
#                         x578
#                         divide(
#                           x578
#                           subtract(
#                             x390
#                             divide(
#                               x578
#                               x366
#                             )
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# #### **GSGP**

# %%
from slim_gsgp.main_gsgp import gsgp  # import the slim library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split  # import the train-test split function
from slim_gsgp.utils.utils import generate_random_uniform  # import the mutation step function

# %%
# Apply the Standard GSGP algorithm
final_tree = gsgp(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', pop_size=100, n_iter=100,
                  reconstruct=True, ms_lower=0, ms_upper=1)

# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   57.22980880737305   |   60.118648529052734     |   0.1385810375213623   |      3           |
# |     ppb                 |       1      |   57.012939453125     |   59.90546417236328      |   0.03135108947753906  |      9           |
# |     ppb                 |       2      |   57.012939453125     |   59.90546417236328      |   0.030820846557617188 |      9           |
# |     ppb                 |       3      |   56.786285400390625  |   59.68736267089844      |   0.03261423110961914  |      15          |
# |     ppb                 |       4      |   56.68245315551758   |   59.5860481262207       |   0.03134322166442871  |      21          |
# |     ppb                 |       5      |   56.06733322143555   |   58.988372802734375     |   0.03223013877868652  |      27          |
# |     ppb                 |       6      |   55.86701583862305   |   58.76530075073242      |   0.03069591522216797  |      33          |
# |     ppb                 |       7      |   55.502357482910156  |   58.42348098754883      |   0.08300304412841797  |      39          |
# |     ppb                 |       8      |   55.239234924316406  |   58.152992248535156     |   0.03052806854248047  |      45          |
# |     ppb                 |       9      |   54.80342102050781   |   57.7288932800293       |   0.032167911529541016 |      51          |
# |     ppb                 |       10     |   54.708988189697266  |   57.5573844909668       |   0.031606197357177734 |      59          |
# |     ppb                 |       11     |   54.45937728881836   |   57.40095520019531      |   0.03142213821411133  |      57          |
# |     ppb                 |       12     |   54.04957580566406   |   57.00214767456055      |   0.03502678871154785  |      63          |
# |     ppb                 |       13     |   53.95264434814453   |   56.907344818115234     |   0.034818172454833984 |      69          |
# |     ppb                 |       14     |   53.757911682128906  |   56.608394622802734     |   0.03813886642456055  |      77          |
# |     ppb                 |       15     |   53.464454650878906  |   56.4351806640625       |   0.03411602973937988  |      81          |
# |     ppb                 |       16     |   53.203575134277344  |   56.09865188598633      |   0.03245091438293457  |      89          |
# |     ppb                 |       17     |   52.99372482299805   |   55.973045349121094     |   0.03193521499633789  |      87          |
# |     ppb                 |       18     |   52.64656448364258   |   55.64015197753906      |   0.032414913177490234 |      93          |
# |     ppb                 |       19     |   52.23220443725586   |   55.196266174316406     |   0.03572392463684082  |      105         |
# |     ppb                 |       20     |   52.23220443725586   |   55.196266174316406     |   0.03615999221801758  |      105         |
# |     ppb                 |       21     |   51.720455169677734  |   54.735504150390625     |   0.040319204330444336 |      111         |
# |     ppb                 |       22     |   51.681514739990234  |   54.639339447021484     |   0.032624006271362305 |      111         |
# |     ppb                 |       23     |   51.171905517578125  |   54.10962677001953      |   0.031469106674194336 |      123         |
# |     ppb                 |       24     |   50.80158233642578   |   53.749305725097656     |   0.032826900482177734 |      129         |
# |     ppb                 |       25     |   50.65827560424805   |   53.613182067871094     |   0.032901763916015625 |      135         |
# |     ppb                 |       88     |   36.820457458496094  |   40.25792694091797      |   0.03481793403625488  |      485         |
# |     ppb                 |       89     |   36.81374740600586   |   40.250396728515625     |   0.030900001525878906 |      491         |
# |     ppb                 |       90     |   36.59601974487305   |   40.03914260864258      |   0.032649993896484375 |      497         |
# |     ppb                 |       91     |   36.394290924072266  |   39.84478759765625      |   0.03222393989562988  |      503         |
# |     ppb                 |       92     |   36.258419036865234  |   39.7132453918457       |   0.034127235412597656 |      503         |
# |     ppb                 |       93     |   35.971187591552734  |   39.43468475341797      |   0.03510785102844238  |      509         |
# |     ppb                 |       94     |   35.88404083251953   |   39.35161590576172      |   0.032572269439697266 |      509         |
# |     ppb                 |       95     |   35.84566116333008   |   39.234893798828125     |   0.03313279151916504  |      521         |
# |     ppb                 |       96     |   35.614078521728516  |   39.09074401855469      |   0.03124094009399414  |      521         |
# |     ppb                 |       97     |   35.57982635498047   |   39.04893493652344      |   0.03141021728515625  |      521         |
# |     ppb                 |       98     |   35.27167510986328   |   38.76980972290039      |   0.031606197357177734 |      533         |
# |     ppb                 |       99     |   35.24334716796875   |   38.744956970214844     |   0.0334320068359375   |      539         |
# |     ppb                 |       100    |   35.182193756103516  |   38.67305374145508      |   0.033921241760253906 |      545         |
# 35.838199615478516

# %% [markdown]
# #### **SLIM**

# %%
from slim_gsgp.main_slim import slim  # import the slim library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split, show_individual  # import the train-test split function
from slim_gsgp.utils.utils import generate_random_uniform  # import the mutation step function

# %%
# Apply the SLIM GSGP algorithm
final_tree = slim(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', slim_version='SLIM+SIG2', pop_size=100, n_iter=100,
                  ms_lower=0, ms_upper=1, p_inflate=0.5)
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   44.542259216308594  |   57.63134765625         |   0.059311866760253906 |      3           |
# |     ppb                 |       1      |   44.542259216308594  |   57.63134765625         |   0.018822908401489258 |      3           |
# |     ppb                 |       2      |   44.470584869384766  |   57.602725982666016     |   0.016718626022338867 |      13          |
# |     ppb                 |       3      |   44.470584869384766  |   57.602725982666016     |   0.016634225845336914 |      13          |
# |     ppb                 |       4      |   44.36399459838867   |   57.57643508911133      |   0.014998912811279297 |      24          |
# |     ppb                 |       5      |   44.35532760620117   |   57.575687408447266     |   0.015594005584716797 |      35          |
# |     ppb                 |       6      |   44.281639099121094  |   57.55645751953125      |   0.019230365753173828 |      46          |
# |     ppb                 |       7      |   44.281639099121094  |   57.55645751953125      |   0.017443180084228516 |      46          |
# |     ppb                 |       8      |   44.25563049316406   |   57.5482063293457       |   0.019757986068725586 |      46          |
# |     ppb                 |       9      |   44.236572265625     |   57.538543701171875     |   0.016973257064819336 |      77          |
# "(np.str_('subtract'), np.str_('x0'), np.str_('x251')) + f((np.str_('multiply'), np.str_('x370'), np.str_('x476')) - (np.str_('subtract'), np.str_('x160'), np.str_('x86'))) + f((np.str_('divide'), np.str_('constant_2.0'), np.str_('x292')) - (np.str_('multiply'), np.str_('constant_3.0'), np.str_('constant__1.0'))) + f((np.str_('multiply'), np.str_('x313'), np.str_('x326')) - (np.str_('cosine'), np.str_('constant_2.0'))) + f((np.str_('multiply'), np.str_('x531'), np.str_('x245')) - (np.str_('subtract'), np.str_('x327'), np.str_('constant_5.0'))) + f((np.str_('multiply'), np.str_('x316'), np.str_('x379')) - (np.str_('cosine'), np.str_('x175'))) + f((np.str_('subtract'), np.str_('x417'), np.str_('x511')) - (np.str_('subtract'), np.str_('x139'), np.str_('constant_2.0'))) + f((np.str_('add'), np.str_('x496'), np.str_('x592')) - (np.str_('subtract'), np.str_('x150'), np.str_('x276'))) + f((np.str_('multiply'), np.str_('x132'), np.str_('x248')) - (np.str_('subtract'), np.str_('x616'), np.str_('x92'))) + f((np.str_('divide'), np.str_('constant_4.0'), np.str_('x195')) - (np.str_('subtract'), np.str_('x366'), np.str_('constant_5.0'))) + f((np.str_('mean'), np.str_('x444'), np.str_('x341')) - (np.str_('subtract'), np.str_('x326'), np.str_('x16'))) + f((np.str_('mean'), np.str_('x227'), np.str_('x250')) - (np.str_('cosine'), np.str_('x317')))"

# %%
# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# 50.721195220947266

# %% [markdown]
# ----

# %% [markdown]
# ### 3. Upload and use a new dataset, download it from: https://epistasislab.github.io/pmlb/

# %% [markdown]
# Actuall Github directory: https://github.com/EpistasisLab/pmlb/blob/master/datasets/1089_USCrime/1089_USCrime.tsv.gz

# %%
import pandas as pd
import os
import torch
from slim_gsgp.utils.utils import train_test_split
from slim_gsgp.datasets.data_loader import load_uscrime

# %%
X, y = load_uscrime(X_y=True)

# %%
X ,y
# Out:
# (tensor([[7.9100e+01, 1.5100e+02, 1.0000e+00, 9.1000e+01, 5.8000e+01, 5.6000e+01,
#           5.1000e+02, 9.5000e+02, 3.3000e+01, 3.0100e+02, 1.0800e+02, 4.1000e+01,
#           3.9400e+02],
#          [1.6350e+02, 1.4300e+02, 0.0000e+00, 1.1300e+02, 1.0300e+02, 9.5000e+01,
#           5.8300e+02, 1.0120e+03, 1.3000e+01, 1.0200e+02, 9.6000e+01, 3.6000e+01,
#           5.5700e+02],
#          [5.7800e+01, 1.4200e+02, 1.0000e+00, 8.9000e+01, 4.5000e+01, 4.4000e+01,
#           5.3300e+02, 9.6900e+02, 1.8000e+01, 2.1900e+02, 9.4000e+01, 3.3000e+01,
#           3.1800e+02],
#          [1.9690e+02, 1.3600e+02, 0.0000e+00, 1.2100e+02, 1.4900e+02, 1.4100e+02,
#           5.7700e+02, 9.9400e+02, 1.5700e+02, 8.0000e+01, 1.0200e+02, 3.9000e+01,
#           6.7300e+02],
#          [1.2340e+02, 1.4100e+02, 0.0000e+00, 1.2100e+02, 1.0900e+02, 1.0100e+02,
#           5.9100e+02, 9.8500e+02, 1.8000e+01, 3.0000e+01, 9.1000e+01, 2.0000e+01,
#           5.7800e+02],
#           5.2200e+02, 9.9600e+02, 4.0000e+01, 2.0800e+02, 7.3000e+01, 2.7000e+01,
#           4.9600e+02],
#          [1.0300e+02, 1.3600e+02, 0.0000e+00, 1.2100e+02, 9.5000e+01, 9.6000e+01,
#           5.7400e+02, 1.0120e+03, 2.9000e+01, 3.6000e+01, 1.1100e+02, 3.7000e+01,
#           6.2200e+02],
#          [4.5500e+01, 1.3900e+02, 1.0000e+00, 8.8000e+01, 4.6000e+01, 4.1000e+01,
#           4.8000e+02, 9.6800e+02, 1.9000e+01, 4.9000e+01, 1.3500e+02, 5.3000e+01,
#           4.5700e+02],
#          [5.0800e+01, 1.2600e+02, 0.0000e+00, 1.0400e+02, 1.0600e+02, 9.7000e+01,
#           5.9900e+02, 9.8900e+02, 4.0000e+01, 2.4000e+01, 7.8000e+01, 2.5000e+01,
#           5.9300e+02],
#          [8.4900e+01, 1.3000e+02, 0.0000e+00, 1.2100e+02, 9.0000e+01, 9.1000e+01,
#           6.2300e+02, 1.0490e+03, 3.0000e+00, 2.2000e+01, 1.1300e+02, 4.0000e+01,
#           5.8800e+02]]),
#  tensor([261., 194., 250., 167., 174., 126., 168., 206., 239., 174., 170., 172.,
#          206., 190., 264., 247., 166., 165., 135., 166., 195., 276., 227., 176.,
#          196., 152., 139., 215., 154., 237., 200., 163., 233., 166., 158., 153.,
#          254., 225., 251., 228., 144., 170., 224., 162., 249., 171., 160.]))

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)

# %% [markdown]
# #### Testing on SLIM:

# %%
from slim_gsgp.main_slim import slim  # import the slim library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import show_individual  # import the train-test split function
from slim_gsgp.utils.utils import generate_random_uniform

# %%
# Apply the SLIM GSGP algorithm
final_tree = slim(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', slim_version='SLIM+SIG2', pop_size=100, n_iter=100,
                  ms_lower=0, ms_upper=1, p_inflate=0.5)
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   86.95361328125      |   67.63053131103516      |   0.023955345153808594 |      3           |
# |     ppb                 |       1      |   86.95361328125      |   67.63053131103516      |   0.011518001556396484 |      3           |
# |     ppb                 |       2      |   86.95361328125      |   67.63053131103516      |   0.010486125946044922 |      3           |
# |     ppb                 |       3      |   86.93455505371094   |   67.63024139404297      |   0.010703086853027344 |      16          |
# |     ppb                 |       4      |   86.93455505371094   |   67.63024139404297      |   0.010743141174316406 |      16          |
# |     ppb                 |       5      |   86.67584228515625   |   67.6285400390625       |   0.009922981262207031 |      40          |
# |     ppb                 |       6      |   86.67584228515625   |   67.6285400390625       |   0.01133584976196289  |      40          |
# %%
show_individual(final_tree, 'sum')
# Out:
# "(np.str_('add'), np.str_('x10'), np.str_('x8')) + f((np.str_('divide'), np.str_('x8'), np.str_('x2')) - (np.str_('multiply'), np.str_('x0'), np.str_('constant__1.0'))) + f((np.str_('divide'), np.str_('x3'), np.str_('constant_3.0')) - (np.str_('cosine'), np.str_('x3'))) + f((np.str_('subtract'), (np.str_('multiply'), np.str_('x7'), np.str_('constant_2.0')), np.str_('x12')) - (np.str_('subtract'), np.str_('constant_5.0'), (np.str_('multiply'), np.str_('x1'), np.str_('x11')))) + f((np.str_('mean'), np.str_('x10'), np.str_('x2')) - (np.str_('subtract'), (np.str_('cosine'), np.str_('x4')), np.str_('x7'))) + f((np.str_('multiply'), np.str_('constant_3.0'), np.str_('x0')) - (np.str_('subtract'), (np.str_('mean'), np.str_('x2'), np.str_('x9')), np.str_('x6'))) + f((np.str_('divide'), np.str_('constant_3.0'), (np.str_('add'), np.str_('constant__1.0'), (np.str_('mean'), np.str_('x11'), np.str_('x3')))) - (np.str_('subtract'), (np.str_('cosine'), (np.str_('cosine'), np.str_('x7'))), (np.str_('mean'), (np.str_('add'), (np.str_('subtract'), np.str_('x2'), np.str_('x8')), np.str_('x7')), np.str_('x9')))) + f((np.str_('mean'), (np.str_('mean'), np.str_('x4'), np.str_('x7')), np.str_('x1')) - (np.str_('add'), (np.str_('mean'), np.str_('x0'), (np.str_('divide'), np.str_('constant_2.0'), (np.str_('cosine'), np.str_('x6')))), (np.str_('subtract'), (np.str_('subtract'), (np.str_('subtract'), (np.str_('subtract'), np.str_('constant_3.0'), np.str_('x2')), np.str_('x0')), np.str_('x5')), (np.str_('add'), np.str_('constant_4.0'), np.str_('x9'))))) + f((np.str_('cosine'), np.str_('constant__1.0')) - (np.str_('subtract'), np.str_('x11'), np.str_('x5'))) + f((np.str_('multiply'), np.str_('x11'), np.str_('x6')) - (np.str_('subtract'), np.str_('constant_2.0'), (np.str_('mean'), np.str_('x0'), np.str_('x9')))) + f((np.str_('multiply'), np.str_('constant_4.0'), np.str_('x10')) - (np.str_('subtract'), (np.str_('subtract'), (np.str_('add'), np.str_('x7'), np.str_('x8')), np.str_('x7')), np.str_('x0'))) + f((np.str_('mean'), np.str_('x9'), np.str_('x8')) - (np.str_('divide'), (np.str_('divide'), (np.str_('multiply'), (np.str_('add'), (np.str_('subtract'), np.str_('x9'), np.str_('x2')), np.str_('constant_2.0')), np.str_('x8')), np.str_('constant_2.0')), (np.str_('add'), np.str_('x4'), (np.str_('multiply'), np.str_('x12'), np.str_('x10')))))"

# %%
# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# 96.54297637939453

# %% [markdown]
# ---

# %% [markdown]
# ## **Part 2: SLIM_GSGP**

# %% [markdown]
# ### 1. Create a new logger level, log = 10, where you store the fitness and size of the second best individual and the worst individual, make sure that everything that is being saved with log = 1 is also saved.

# %% [markdown]
# What needs to be done:
# - log selection is changed on **slim_config.py** *slim_gsgp_solve_parameters*
# - log == 10 was added into slim_gsgp.solve().

# %% [markdown]
# Testing on SLIM:

# %%
from slim_gsgp.main_slim import slim  # import the slim library
from slim_gsgp.datasets.data_loader import load_airfoil, load_ppb # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split, show_individual  # import the train-test split function
from slim_gsgp.utils.utils import generate_random_uniform  # import the mutation step function

# %%
X, y = load_airfoil(X_y=True)
#X, y = load_ppb(X_y=True)
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)

# %%
# Apply the SLIM GSGP algorithm
final_tree = slim(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', slim_version='SLIM+SIG2', pop_size=100, n_iter=100,
                  ms_lower=0, ms_upper=1, p_inflate=0.5)

# Show the best individual structure at the last generation
print(show_individual(final_tree, operator='sum'))

# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   38.03727722167969   |   39.9749641418457       |   0.029391765594482422 |      3           |
# |     ppb                 |       1      |   38.03727722167969   |   39.9749641418457       |   0.017300844192504883 |      3           |
# |     ppb                 |       2      |   37.77348327636719   |   39.68068313598633      |   0.015926837921142578 |      14          |
# |     ppb                 |       3      |   37.53711700439453   |   39.4355354309082       |   0.013244867324829102 |      46          |
# |     ppb                 |       4      |   37.431617736816406  |   39.32868957519531      |   0.013576030731201172 |      65          |
# |     ppb                 |       5      |   37.281558990478516  |   39.16392517089844      |   0.013163089752197266 |      59          |
# |     ppb                 |       6      |   37.066410064697266  |   38.97568130493164      |   0.011886835098266602 |      102         |
# |     ppb                 |       7      |   37.027305603027344  |   38.931819915771484     |   0.011799097061157227 |      113         |
# |     ppb                 |       8      |   36.96699142456055   |   38.86281967163086      |   0.01528024673461914  |      137         |
# |     ppb                 |       9      |   36.96699142456055   |   38.86281967163086      |   0.013211965560913086 |      137         |
# |     ppb                 |       10     |   36.96699142456055   |   38.86281967163086      |   0.01537013053894043  |      137         |
# |     ppb                 |       11     |   36.93621063232422   |   38.7879638671875       |   0.013466119766235352 |      87          |
# |     ppb                 |       12     |   36.7456169128418    |   38.61579132080078      |   0.013374805450439453 |      119         |
# |     ppb                 |       13     |   36.7456169128418    |   38.61579132080078      |   0.010245084762573242 |      119         |
# |     ppb                 |       14     |   36.55183410644531   |   38.40119552612305      |   0.01181793212890625  |      129         |
# |     ppb                 |       15     |   36.55183410644531   |   38.40119552612305      |   0.010777950286865234 |      129         |
# |     ppb                 |       16     |   36.55183410644531   |   38.40119552612305      |   0.010421037673950195 |      129         |
# |     ppb                 |       80     |   34.926822662353516  |   36.486881256103516     |   0.007930994033813477 |      138         |
# |     ppb                 |       81     |   34.926822662353516  |   36.486881256103516     |   0.005440950393676758 |      138         |
# |     ppb                 |       82     |   34.926822662353516  |   36.486881256103516     |   0.005946159362792969 |      138         |
# |     ppb                 |       83     |   34.926822662353516  |   36.486881256103516     |   0.006106853485107422 |      138         |
# |     ppb                 |       84     |   34.85605239868164   |   36.421302795410156     |   0.007735013961791992 |      161         |
# |     ppb                 |       85     |   34.85605239868164   |   36.421302795410156     |   0.008516073226928711 |      161         |
# |     ppb                 |       86     |   34.85605239868164   |   36.421302795410156     |   0.0073702335357666016|      161         |
# |     ppb                 |       87     |   34.85605239868164   |   36.421302795410156     |   0.006654977798461914 |      161         |
# |     ppb                 |       88     |   34.85605239868164   |   36.421302795410156     |   0.006553173065185547 |      161         |
# |     ppb                 |       89     |   34.85605239868164   |   36.421302795410156     |   0.005841732025146484 |      161         |
# |     ppb                 |       90     |   34.85605239868164   |   36.421302795410156     |   0.008040189743041992 |      161         |
# |     ppb                 |       91     |   34.85605239868164   |   36.421302795410156     |   0.007387876510620117 |      161         |
# |     ppb                 |       92     |   34.85605239868164   |   36.421302795410156     |   0.007756233215332031 |      161         |
# |     ppb                 |       93     |   34.85605239868164   |   36.421302795410156     |   0.006331205368041992 |      161         |
# |     ppb                 |       94     |   34.85605239868164   |   36.421302795410156     |   0.008165121078491211 |      161         |
# |     ppb                 |       95     |   34.84450149536133   |   36.38850021362305      |   0.006352901458740234 |      140         |
# |     ppb                 |       96     |   34.84450149536133   |   36.38850021362305      |   0.006947040557861328 |      140         |
# |     ppb                 |       97     |   34.84450149536133   |   36.38850021362305      |   0.006930351257324219 |      140         |
# |     ppb                 |       98     |   34.84450149536133   |   36.38850021362305      |   0.008124113082885742 |      140         |
# |     ppb                 |       99     |   34.84450149536133   |   36.38850021362305      |   0.007231950759887695 |      140         |
# |     ppb                 |       100    |   34.84450149536133   |   36.38850021362305      |   0.007661104202270508 |      140         |
# (np.str_('add'), np.str_('x3'), np.str_('x3')) + f((np.str_('multiply'), np.str_('x4'), np.str_('constant__1.0')) - (np.str_('subtract'), np.str_('x2'), np.str_('x0'))) + f((np.str_('subtract'), np.str_('x3'), np.str_('x2')) - (np.str_('divide'), (np.str_('multiply'), (np.str_('multiply'), (np.str_('divide'), np.str_('x0'), np.str_('constant__1.0')), np.str_('constant_4.0')), np.str_('x0')), np.str_('x2'))) + f((np.str_('add'), np.str_('x4'), np.str_('constant_3.0')) - (np.str_('subtract'), (np.str_('subtract'), (np.str_('subtract'), np.str_('constant_3.0'), (np.str_('multiply'), np.str_('constant_2.0'), (np.str_('mean'), np.str_('x0'), np.str_('x2')))), np.str_('constant_3.0')), np.str_('x3'))) + f((np.str_('multiply'), np.str_('constant_3.0'), np.str_('x1')) - (np.str_('divide'), np.str_('x0'), (np.str_('subtract'), np.str_('constant_3.0'), np.str_('x3')))) + f((np.str_('add'), np.str_('constant_5.0'), np.str_('constant_4.0')) - (np.str_('subtract'), np.str_('x0'), (np.str_('multiply'), np.str_('constant_4.0'), (np.str_('subtract'), (np.str_('add'), (np.str_('cosine'), np.str_('x4')), np.str_('x3')), (np.str_('subtract'), (np.str_('mean'), np.str_('constant_3.0'), np.str_('x0')), np.str_('x0')))))) + f((np.str_('subtract'), (np.str_('multiply'), np.str_('x3'), np.str_('x0')), np.str_('x0')) - (np.str_('subtract'), np.str_('constant_4.0'), np.str_('constant_5.0'))) + f((np.str_('divide'), np.str_('x3'), np.str_('x1')) - (np.str_('divide'), np.str_('x3'), (np.str_('cosine'), (np.str_('add'), np.str_('x2'), np.str_('constant_4.0'))))) + f((np.str_('divide'), np.str_('constant_3.0'), np.str_('x2')) - (np.str_('cosine'), (np.str_('subtract'), np.str_('x0'), np.str_('x4')))) + f((np.str_('add'), np.str_('x3'), np.str_('x1')) - (np.str_('multiply'), np.str_('x1'), (np.str_('cosine'), (np.str_('mean'), (np.str_('multiply'), np.str_('constant_4.0'), np.str_('x4')), np.str_('constant_4.0')))))
# 36.11484146118164

# %% [markdown]
# ### 2. Create and use a crossover operator swaps the first block of the two parent trees.

# %% [markdown]
# - To create a Crossover Operator that swaps the first of the two blocks of the two parent trees, we first need to understand the way trees are saved in SLIM.
# - SLIM is using GSGP's Geometric Crossover, so the approach should be similar to that.
#
# If we check *slim_gsgp.py*, we see that crossover is not yet applied, so this algorithm is always running without crossover. This being said, part 1 of implementing a new crossover is to make sure regular geometric_xo works correctly on SLIM_GSGP.

# %% [markdown]
# **STEP 1: Adding Crossover to SLIM_GSGP algorithm code:**

# %% [markdown]
# For this approach, we will consider the most general way possible to implement crossover in slim_gsgp. What this means it that, independetly of the crossover used, the goal is to be able to simply create/change crossover operator and let the algorithm be fully functional, with no need to change the base algorithm.
#
# To do so, the most common inputs of crossovers need to be considered, namely: random_tree, tree1, tree2, if we are testing (testing), if there is new_data (new_data).\
# In the same way, we also need to consider the possibility of having only 1 output tree (geometric_semantic_crossover) or 2.

# %% [markdown]
# **Possible solutions:**
# 1.  Consider always the most outside level possible, that is, always generate all necessary inputs specified above.
# 2. Check if there is any possibility of checking the necessary inputs of the operator used.

# %% [markdown]
# Start by checking **option 2**:

# %% [markdown]
# This way, we can easily iterate over each needed parameter.
#
# **SWAP_BASE_CROSSOVER:**

# %% [markdown]
# - The only thing I have not done is check the **max_depth** after crossover, as I don't know how to deal with it (with inflate we simply do a copy_parent or deflate).

# %%
from slim_gsgp.main_slim import slim  # import the slim library
from slim_gsgp.datasets.data_loader import load_airfoil, load_ppb # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split, show_individual  # import the train-test split function
from slim_gsgp.utils.utils import generate_random_uniform  # import the mutation step function

# %%
#X, y = load_airfoil(X_y=True)
X, y = load_ppb(X_y=True)
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)#

# %%
# Apply the SLIM GSGP algorithm
final_tree = slim(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', slim_version='SLIM+SIG2', pop_size=100, n_iter=100,
                  ms_lower=0, ms_upper=1, p_inflate=0.5)

# Show the best individual structure at the last generation
print(show_individual(final_tree, operator='sum'))

# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   44.542259216308594  |   57.63134765625         |   0.09506916999816895  |      3           |
# |     ppb                 |       1      |   44.540802001953125  |   57.631412506103516     |   0.024104833602905273 |      13          |
# |     ppb                 |       2      |   44.540802001953125  |   57.631412506103516     |   0.021932125091552734 |      13          |
# |     ppb                 |       3      |   44.520267486572266  |   57.63651657104492      |   0.02266216278076172  |      13          |
# |     ppb                 |       4      |   44.376983642578125  |   57.58342742919922      |   0.02264404296875     |      13          |
# |     ppb                 |       5      |   44.376983642578125  |   57.58342742919922      |   0.022135019302368164 |      13          |
# |     ppb                 |       6      |   44.36595916748047   |   57.600894927978516     |   0.02031707763671875  |      25          |
# |     ppb                 |       7      |   44.36595916748047   |   57.600894927978516     |   0.01741790771484375  |      25          |
# |     ppb                 |       8      |   44.31953811645508   |   57.62567901611328      |   0.02325606346130371  |      35          |
# |     ppb                 |       9      |   44.25527572631836   |   57.608341217041016     |   0.024158954620361328 |      46          |
# |     ppb                 |       10     |   44.25527572631836   |   57.608341217041016     |   0.026702880859375    |      46          |
# |     ppb                 |       11     |   44.25527572631836   |   57.608341217041016     |   0.019988298416137695 |      46          |
# |     ppb                 |       12     |   44.192344665527344  |   57.545257568359375     |   0.02132391929626465  |      46          |
# |     ppb                 |       13     |   44.15312194824219   |   57.58705520629883      |   0.02055978775024414  |      57          |
# |     ppb                 |       14     |   44.1014518737793    |   57.5748176574707       |   0.02276611328125     |      57          |
# |     ppb                 |       15     |   44.0917854309082    |   57.55275344848633      |   0.02246403694152832  |      68          |
# |     ppb                 |       16     |   44.065494537353516  |   57.57387161254883      |   0.022762060165405273 |      79          |
# |     ppb                 |       17     |   44.04408264160156   |   57.5697135925293       |   0.02330493927001953  |      89          |
# |     ppb                 |       18     |   43.97305679321289   |   57.5499267578125       |   0.022433042526245117 |      99          |
# |     ppb                 |       19     |   43.97305679321289   |   57.5499267578125       |   0.024143218994140625 |      99          |
# |     ppb                 |       20     |   43.93041229248047   |   57.55941390991211      |   0.021982908248901367 |      110         |
# |     ppb                 |       21     |   43.874290466308594  |   57.552146911621094     |   0.021955013275146484 |      121         |
# |     ppb                 |       22     |   43.874290466308594  |   57.552146911621094     |   0.02073979377746582  |      121         |
# |     ppb                 |       23     |   43.874290466308594  |   57.552146911621094     |   0.018501996994018555 |      121         |
# |     ppb                 |       24     |   43.85820007324219   |   57.42964172363281      |   0.021432876586914062 |      120         |
# |     ppb                 |       25     |   43.83621597290039   |   57.54336929321289      |   0.0182340145111084   |      111         |
# |     ppb                 |       89     |   43.3724479675293    |   57.50303649902344      |   0.011932849884033203 |      122         |
# |     ppb                 |       90     |   43.3724479675293    |   57.50303649902344      |   0.01024007797241211  |      122         |
# |     ppb                 |       91     |   43.3724479675293    |   57.50303649902344      |   0.008777856826782227 |      122         |
# |     ppb                 |       92     |   43.3724479675293    |   57.50303649902344      |   0.012182950973510742 |      122         |
# |     ppb                 |       93     |   43.295005798339844  |   57.45695114135742      |   0.009373903274536133 |      122         |
# |     ppb                 |       94     |   43.295005798339844  |   57.45695114135742      |   0.011525869369506836 |      122         |
# |     ppb                 |       95     |   43.295005798339844  |   57.45695114135742      |   0.012347221374511719 |      122         |
# |     ppb                 |       96     |   43.295005798339844  |   57.45695114135742      |   0.010234832763671875 |      122         |
# |     ppb                 |       97     |   43.295005798339844  |   57.45695114135742      |   0.011220932006835938 |      122         |
# |     ppb                 |       98     |   43.295005798339844  |   57.45695114135742      |   0.011831998825073242 |      122         |
# |     ppb                 |       99     |   43.295005798339844  |   57.45695114135742      |   0.012219905853271484 |      122         |
# |     ppb                 |       100    |   43.295005798339844  |   57.45695114135742      |   0.009669780731201172 |      122         |
# (np.str_('subtract'), np.str_('x0'), np.str_('x251')) + f((np.str_('divide'), np.str_('constant_2.0'), np.str_('x9')) - (np.str_('subtract'), np.str_('constant__1.0'), np.str_('x192'))) + f((np.str_('mean'), np.str_('x481'), np.str_('x538')) - (np.str_('subtract'), np.str_('x120'), np.str_('x60'))) + f((np.str_('subtract'), np.str_('x67'), np.str_('constant_4.0')) - (np.str_('subtract'), np.str_('x294'), np.str_('constant_5.0'))) + f((np.str_('multiply'), np.str_('x239'), np.str_('x218')) - (np.str_('cosine'), np.str_('x322'))) + f((np.str_('multiply'), np.str_('x532'), np.str_('constant_2.0')) - (np.str_('subtract'), np.str_('constant__1.0'), np.str_('x547'))) + f((np.str_('multiply'), np.str_('x386'), np.str_('x522')) - (np.str_('mean'), np.str_('x360'), np.str_('x579'))) + f((np.str_('mean'), np.str_('constant__1.0'), np.str_('x491')) - (np.str_('multiply'), np.str_('constant_5.0'), np.str_('constant__1.0'))) + f((np.str_('divide'), np.str_('x596'), np.str_('x2')) - (np.str_('subtract'), np.str_('constant__1.0'), np.str_('x586'))) + f((np.str_('mean'), np.str_('x549'), np.str_('x95')) - (np.str_('subtract'), np.str_('constant_2.0'), np.str_('x295'))) + f((np.str_('cosine'), np.str_('x444')) - (np.str_('divide'), np.str_('constant_2.0'), np.str_('x341'))) + f((np.str_('divide'), np.str_('x133'), np.str_('x522')) - (np.str_('subtract'), np.str_('constant_4.0'), np.str_('x207')))
# 50.7060546875

# %% [markdown]
# **GEOMETRIC_CROSSOVER**

# %% [markdown]
# My biggest question is how geometric_crossover actually works with the Individuals class, that have multiple trees inside [T1, T2, T3...]
#
# - Where i am today is that i was assuming that we were always dealing with trees of size = 1, that is, using only 1 tree, when in fact SLIM_GSGP works with individuals that are lists of trees and we should take into consideration all the trees we have. This being said, i have actually no idea how Geometric_XO is aplied when we have multiple trees in an individual.... if we have [T1, T2, T3] and [T4, T5], how do we crossover these to individuals, creating only one final individual?
# -  A possible solution is to select a tree from each individual and perform geometric xo to it, but it doesnt really make sense as you would always have individuals with size = 1.

# %% [markdown]
# ### 3. Create and use a new selection algorithm that takes into account both the fitness and the number of nodes (could be nested tournament selection)

# %% [markdown]
# To take into account both fitness (ind.fitness) and number of nodes (ind.nodes_count) we can simply use a nested tournament selection.\
# In this selection, we will first select a population of individuals that have the "best fitness" and from that population, we select the indiidual with the smallest number of nodes. In this case, if the pool_size is 2, we select the 2 individuals with best fitness and from those, the node with the smallest number of nodes.

# %% [markdown]
# **NOTE:** To actually apply nested_selection, you need to change both consig and main slim....

# %%
from slim_gsgp.main_slim import slim  # import the slim library
from slim_gsgp.datasets.data_loader import load_airfoil, load_ppb # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split, show_individual  # import the train-test split function
from slim_gsgp.utils.utils import generate_random_uniform  # import the mutation step function

# %%
#X, y = load_airfoil(X_y=True)
X, y = load_ppb(X_y=True)
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)#

# %%
# Apply the SLIM GSGP algorithm
final_tree = slim(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', slim_version='SLIM+SIG2', pop_size=100, n_iter=100,
                  ms_lower=0, ms_upper=1, p_inflate=0.5)

# Show the best individual structure at the last generation
print(show_individual(final_tree, operator='sum'))

# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   44.542259216308594  |   57.63134765625         |   0.06141996383666992  |      3           |
# |     ppb                 |       1      |   44.540802001953125  |   57.631412506103516     |   0.026263713836669922 |      13          |
# |     ppb                 |       2      |   44.540802001953125  |   57.631412506103516     |   0.020376920700073242 |      13          |
# |     ppb                 |       3      |   44.540802001953125  |   57.631412506103516     |   0.02352309226989746  |      13          |
# |     ppb                 |       4      |   44.540802001953125  |   57.631412506103516     |   0.023378849029541016 |      13          |
# |     ppb                 |       5      |   44.540802001953125  |   57.631412506103516     |   0.017817974090576172 |      13          |
# |     ppb                 |       6      |   44.540802001953125  |   57.631412506103516     |   0.022656917572021484 |      13          |
# |     ppb                 |       7      |   44.540802001953125  |   57.631412506103516     |   0.019106149673461914 |      13          |
# |     ppb                 |       8      |   44.50877380371094   |   57.621429443359375     |   0.019871950149536133 |      14          |
# |     ppb                 |       9      |   44.507591247558594  |   57.62092971801758      |   0.02696394920349121  |      13          |
# |     ppb                 |       10     |   44.5003776550293    |   57.61798095703125      |   0.025583982467651367 |      13          |
