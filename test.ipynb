# %% [markdown]
# # Testing gsgp_slim library:

# %% [markdown]
# ### Install library:

# %%
pip install gsgp_slim
# Out:
# Requirement already satisfied: gsgp_slim in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (0.1.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from gsgp_slim) (1.26.4)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from gsgp_slim) (2.2.1)
# Requirement already satisfied: torch in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from gsgp_slim) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from pandas->gsgp_slim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from pandas->gsgp_slim) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from pandas->gsgp_slim) (2024.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch->gsgp_slim) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch->gsgp_slim) (4.11.0)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch->gsgp_slim) (1.13.2)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch->gsgp_slim) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch->gsgp_slim) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch->gsgp_slim) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->gsgp_slim) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from jinja2->torch->gsgp_slim) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from sympy->torch->gsgp_slim) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Install Requirements:

# %%
pip install -r requirements.txt
# Out:
# Collecting numpy~=2.0.2 (from -r requirements.txt (line 1))
#   Downloading numpy-2.0.2-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# Collecting pandas~=2.2.3 (from -r requirements.txt (line 2))
#   Downloading pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting torch~=2.4.1 (from -r requirements.txt (line 3))
#   Using cached torch-2.4.1-cp312-none-macosx_11_0_arm64.whl.metadata (26 kB)
# Requirement already satisfied: joblib==1.4.2 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (1.4.2)
# Collecting pytest~=8.3.3 (from -r requirements.txt (line 5))
#   Downloading pytest-8.3.3-py3-none-any.whl.metadata (7.5 kB)
# Collecting setuptools~=75.1.0 (from -r requirements.txt (line 6))
#   Using cached setuptools-75.1.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: scikit-learn~=1.5.2 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.5.2)
# Collecting scipy~=1.13.1 (from -r requirements.txt (line 8))
#   Downloading scipy-1.13.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from pandas~=2.2.3->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from pandas~=2.2.3->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from pandas~=2.2.3->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch~=2.4.1->-r requirements.txt (line 3)) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch~=2.4.1->-r requirements.txt (line 3)) (4.11.0)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch~=2.4.1->-r requirements.txt (line 3)) (1.13.2)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch~=2.4.1->-r requirements.txt (line 3)) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch~=2.4.1->-r requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from torch~=2.4.1->-r requirements.txt (line 3)) (2024.6.1)
# Collecting iniconfig (from pytest~=8.3.3->-r requirements.txt (line 5))
#   Downloading iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from pytest~=8.3.3->-r requirements.txt (line 5)) (24.1)
# Collecting pluggy<2,>=1.5 (from pytest~=8.3.3->-r requirements.txt (line 5))
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from scikit-learn~=1.5.2->-r requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas~=2.2.3->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from jinja2->torch~=2.4.1->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from sympy->torch~=2.4.1->-r requirements.txt (line 3)) (1.3.0)
# Downloading numpy-2.0.2-cp312-cp312-macosx_14_0_arm64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 8.3 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.2.3-cp312-cp312-macosx_11_0_arm64.whl (11.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 8.8 MB/s eta 0:00:00a 0:00:01
# Using cached torch-2.4.1-cp312-none-macosx_11_0_arm64.whl (62.1 MB)
# Downloading pytest-8.3.3-py3-none-any.whl (342 kB)
# Using cached setuptools-75.1.0-py3-none-any.whl (1.2 MB)
# Downloading scipy-1.13.1-cp312-cp312-macosx_12_0_arm64.whl (30.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.4/30.4 MB 10.5 MB/s eta 0:00:0000:0100:01
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Installing collected packages: setuptools, pluggy, numpy, iniconfig, torch, scipy, pytest, pandas
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 72.1.0
#     Uninstalling setuptools-72.1.0:
#       Successfully uninstalled setuptools-72.1.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1
#     Uninstalling torch-2.2.1:
#       Successfully uninstalled torch-2.2.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.1
#     Uninstalling pandas-2.2.1:
#       Successfully uninstalled pandas-2.2.1
# Successfully installed iniconfig-2.0.0 numpy-2.0.2 pandas-2.2.3 pluggy-1.5.0 pytest-8.3.3 scipy-1.13.1 setuptools-75.1.0 torch-2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Running GP:

# %%
#pip install scipy
#!pip install sklearn --> deprecated
#!pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/envs/gsgp_env/lib/python3.12/site-packages (from scikit-learn) (1.14.1)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 61.9 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.5.2 threadpoolctl-3.5.0

# %%
from slim_gsgp.main_gp import gp  # import the slim_gsgp library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split  # import the train-test split function

# %%
# Load the PPB dataset
X, y = load_ppb(X_y=True)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)

# %%
# Apply the GP algorithm
final_tree = gp(X_train=X_train, y_train=y_train,
                X_test=X_val, y_test=y_val,
                dataset_name='ppb', pop_size=100, n_iter=100)

# Show the best individual structure at the last generation
final_tree.print_tree_representation()

# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   40.88839340209961   |   43.040855407714844     |   0.05284690856933594  |      15          |
# |     ppb                 |       1      |   40.71933364868164   |   42.63808822631836      |   0.0075931549072265625|      15          |
# |     ppb                 |       2      |   39.167301177978516  |   41.406654357910156     |   0.0064470767974853516|      3           |
# |     ppb                 |       3      |   30.20241355895996   |   32.765968322753906     |   0.00580906867980957  |      3           |
# |     ppb                 |       4      |   30.20241355895996   |   32.765968322753906     |   0.006091117858886719 |      3           |
# |     ppb                 |       5      |   30.20241355895996   |   32.765968322753906     |   0.004420042037963867 |      3           |
# |     ppb                 |       6      |   30.20241355895996   |   32.765968322753906     |   0.0066678524017333984|      3           |
# |     ppb                 |       7      |   30.20241355895996   |   32.765968322753906     |   0.005361080169677734 |      3           |
#       x457
#       add(
#         x457
#         add(
#           x524
#           add(
#             x457
#             add(
#               x15
#               divide(
#                 x605
#                 add(
#                   x407
#                   add(
#                     x79
#                     add(
#                       x457
#                       add(
#                         x524
#                         add(
#                           x407
#                           subtract(
#                             x379
#                             x100
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   add(
#     x457
#     add(
#       x524
#       add(
#         x457
#         add(
#           x15
#           divide(
#             x605
#             add(
#               x407
#               add(
#                 x79
#                 add(
#                   x457
#                   add(
#                     x524
#                     add(
#                       x407
#                       add(
#                         x457
#                         divide(
#                           x605
#                           divide(
#                             x359
#                             subtract(
#                               x195
#                               add(
#                                 x524
#                                 x100
#                               )
#                             )
#                           )
#                         )
#                       )
#                     )
#                   )
#                 )
#               )
#             )
#           )
#         )
#       )
#     )
#   )
# )
#
# 28.124900817871094

# %% [markdown]
# ## Running standard GSGP:

# %%
from slim_gsgp.main_gsgp import gsgp  # import the slim_gsgp library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split  # import the train-test split function

# %%
# Load the PPB dataset
X, y = load_ppb(X_y=True)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)

# %%
# Apply the Standard GSGP algorithm
final_tree = gsgp(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', pop_size=100, n_iter=100,
                  reconstruct=True, ms_lower=0, ms_upper=1)

# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   57.22980880737305   |   60.118648529052734     |   0.1286931037902832   |      3           |
# |     ppb                 |       1      |   57.012939453125     |   59.90546417236328      |   0.030501127243041992 |      9           |
# |     ppb                 |       2      |   57.012939453125     |   59.90546417236328      |   0.028802156448364258 |      9           |
# |     ppb                 |       3      |   56.786285400390625  |   59.68736267089844      |   0.08918404579162598  |      15          |
# |     ppb                 |       4      |   56.68245315551758   |   59.5860481262207       |   0.028712987899780273 |      21          |
# |     ppb                 |       5      |   56.06733322143555   |   58.988372802734375     |   0.030703067779541016 |      27          |
# |     ppb                 |       6      |   55.86701583862305   |   58.76530075073242      |   0.030072689056396484 |      33          |
# |     ppb                 |       7      |   55.502357482910156  |   58.42348098754883      |   0.02864527702331543  |      39          |
# |     ppb                 |       8      |   55.239234924316406  |   58.152992248535156     |   0.028857946395874023 |      45          |
# |     ppb                 |       9      |   54.80342102050781   |   57.7288932800293       |   0.02756786346435547  |      51          |
# |     ppb                 |       10     |   54.708988189697266  |   57.5573844909668       |   0.02857494354248047  |      59          |
# |     ppb                 |       73     |   39.77593231201172   |   43.16191101074219      |   0.029730796813964844 |      401         |
# |     ppb                 |       74     |   39.521095275878906  |   42.940956115722656     |   0.0288240909576416   |      407         |
# |     ppb                 |       75     |   39.51701354980469   |   42.93761444091797      |   0.03196430206298828  |      413         |
# |     ppb                 |       76     |   39.169898986816406  |   42.55314254760742      |   0.031222105026245117 |      419         |
# |     ppb                 |       77     |   39.03480911254883   |   42.32316207885742      |   0.03048396110534668  |      423         |
# |     ppb                 |       78     |   38.6717529296875    |   42.11921310424805      |   0.08817195892333984  |      431         |
# |     ppb                 |       79     |   38.487369537353516  |   41.928253173828125     |   0.02880096435546875  |      437         |
# |     ppb                 |       80     |   37.931678771972656  |   41.389984130859375     |   0.02874588966369629  |      443         |
# |     ppb                 |       81     |   37.931678771972656  |   41.389984130859375     |   0.029098033905029297 |      443         |
# |     ppb                 |       82     |   37.931678771972656  |   41.389984130859375     |   0.027749300003051758 |      443         |
# |     ppb                 |       83     |   37.60837936401367   |   41.0407829284668       |   0.028512001037597656 |      461         |
# |     ppb                 |       84     |   37.516109466552734  |   40.932525634765625     |   0.029298067092895508 |      467         |
# |     ppb                 |       85     |   37.295169830322266  |   40.7387580871582       |   0.02947092056274414  |      467         |
# |     ppb                 |       86     |   37.295169830322266  |   40.7387580871582       |   0.03000187873840332  |      467         |
# |     ppb                 |       87     |   37.04168701171875   |   40.5279426574707       |   0.030610084533691406 |      479         |
# |     ppb                 |       88     |   36.820457458496094  |   40.25792694091797      |   0.03853583335876465  |      485         |
# |     ppb                 |       89     |   36.81374740600586   |   40.250396728515625     |   0.031513214111328125 |      491         |
# |     ppb                 |       90     |   36.59601974487305   |   40.03914260864258      |   0.032943010330200195 |      497         |
# |     ppb                 |       91     |   36.394290924072266  |   39.84478759765625      |   0.029970169067382812 |      503         |
# |     ppb                 |       92     |   36.258419036865234  |   39.7132453918457       |   0.0344388484954834   |      503         |
# |     ppb                 |       93     |   35.971187591552734  |   39.43468475341797      |   0.030453205108642578 |      509         |
# |     ppb                 |       94     |   35.88404083251953   |   39.35161590576172      |   0.031416893005371094 |      509         |
# |     ppb                 |       95     |   35.84566116333008   |   39.234893798828125     |   0.028017044067382812 |      521         |
# |     ppb                 |       96     |   35.614078521728516  |   39.09074401855469      |   0.031239032745361328 |      521         |
# |     ppb                 |       97     |   35.57982635498047   |   39.04893493652344      |   0.03225302696228027  |      521         |
# |     ppb                 |       98     |   35.27167510986328   |   38.76980972290039      |   0.03389787673950195  |      533         |
# |     ppb                 |       99     |   35.24334716796875   |   38.744956970214844     |   0.03294706344604492  |      539         |
# |     ppb                 |       100    |   35.182193756103516  |   38.67305374145508      |   0.031152009963989258 |      545         |
# 35.838199615478516

# %% [markdown]
# ## Running SLIM-GSGP:

# %%
from slim_gsgp.main_slim import slim  # import the slim_gsgp library
from slim_gsgp.datasets.data_loader import load_ppb  # import the loader for the dataset PPB
from slim_gsgp.evaluators.fitness_functions import rmse  # import the rmse fitness metric
from slim_gsgp.utils.utils import train_test_split  # import the train-test split function

# %%
X, y = load_ppb(X_y=True)

# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, p_test=0.4)

# Split the test set into validation and test sets
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, p_test=0.5)

# %%
# Apply the SLIM GSGP algorithm
final_tree = slim(X_train=X_train, y_train=y_train,
                  X_test=X_val, y_test=y_val,
                  dataset_name='ppb', slim_version='SLIM+SIG2', pop_size=100, n_iter=100,
                  ms_lower=0, ms_upper=1, p_inflate=0.5)

# Show the best individual structure at the last generation
final_tree.print_tree_representation()

# Get the prediction of the best individual on the test set
predictions = final_tree.predict(X_test)

# Compute and print the RMSE on the test set
print(float(rmse(y_true=y_test, y_pred=predictions)))
# Out:
# Verbose Reporter
# -----------------------------------------------------------------------------------------------------------------------------------------
# |         Dataset         |  Generation  |     Train Fitness     |       Test Fitness       |        Timing          |      Nodes       |
# -----------------------------------------------------------------------------------------------------------------------------------------
# |     ppb                 |       0      |   44.30246353149414   |   46.856666564941406     |   0.051442861557006836 |      3           |
# |     ppb                 |       1      |   44.30246353149414   |   46.856666564941406     |   0.0182342529296875   |      3           |
# |     ppb                 |       2      |   44.30246353149414   |   46.856666564941406     |   0.016237974166870117 |      3           |
# |     ppb                 |       3      |   44.18924331665039   |   46.75093078613281      |   0.02097606658935547  |      14          |
# |     ppb                 |       4      |   44.0585823059082    |   46.604698181152344     |   0.017834901809692383 |      14          |
# |     ppb                 |       5      |   43.43790054321289   |   46.02116775512695      |   0.019355058670043945 |      25          |
# |     ppb                 |       6      |   43.246219635009766  |   45.83444595336914      |   0.016655921936035156 |      36          |
# |     ppb                 |       7      |   43.246219635009766  |   45.83444595336914      |   0.018229007720947266 |      36          |
# |     ppb                 |       8      |   43.246219635009766  |   45.83444595336914      |   0.019459009170532227 |      36          |
# |     ppb                 |       9      |   43.246219635009766  |   45.83444595336914      |   0.019295930862426758 |      36          |
# |     ppb                 |       10     |   43.246219635009766  |   45.83444595336914      |   0.017079591751098633 |      36          |
# |     ppb                 |       11     |   43.22260284423828   |   45.8176383972168       |   0.01792597770690918  |      25          |
# |     ppb                 |       12     |   43.06111145019531   |   45.66157150268555      |   0.020933151245117188 |      36          |
# |     ppb                 |       13     |   43.001094818115234  |   45.588382720947266     |   0.018405914306640625 |      47          |
# |     ppb                 |       14     |   42.999237060546875  |   45.599151611328125     |   0.01660013198852539  |      80          |
# |     ppb                 |       15     |   42.78394317626953   |   45.37522506713867      |   0.0189359188079834   |      58          |
# |     ppb                 |       16     |   42.64092254638672   |   45.2568244934082       |   0.019049882888793945 |      102         |
# |     ppb                 |       17     |   42.528114318847656  |   45.144134521484375     |   0.0176699161529541   |      113         |
# |     ppb                 |       18     |   42.34349060058594   |   44.96499252319336      |   0.01998114585876465  |      124         |
# |     ppb                 |       19     |   42.34349060058594   |   44.96499252319336      |   0.01488804817199707  |      124         |
# |     ppb                 |       20     |   42.2943115234375    |   44.90407943725586      |   0.01656794548034668  |      124         |
# |     ppb                 |       21     |   42.2943115234375    |   44.90407943725586      |   0.01622915267944336  |      124         |
# |     ppb                 |       22     |   42.13896560668945   |   44.768531799316406     |   0.012223958969116211 |      113         |
# |     ppb                 |       54     |   40.23365783691406   |   43.00218200683594      |   0.011343955993652344 |      124         |
# |     ppb                 |       55     |   40.23365783691406   |   43.00218200683594      |   0.013985872268676758 |      124         |
# |     ppb                 |       56     |   40.23365783691406   |   43.00218200683594      |   0.01373910903930664  |      124         |
# |     ppb                 |       57     |   40.23365783691406   |   43.00218200683594      |   0.015770912170410156 |      124         |
# |     ppb                 |       58     |   40.17013168334961   |   42.96229934692383      |   0.013010025024414062 |      113         |
# |     ppb                 |       59     |   40.067588806152344  |   42.83238220214844      |   0.015043020248413086 |      124         |
# |     ppb                 |       60     |   40.067588806152344  |   42.83238220214844      |   0.012778997421264648 |      124         |
# |     ppb                 |       61     |   40.067588806152344  |   42.83238220214844      |   0.015321969985961914 |      124         |
# |     ppb                 |       62     |   40.067588806152344  |   42.83238220214844      |   0.011221170425415039 |      124         |
# |     ppb                 |       63     |   40.067588806152344  |   42.83238220214844      |   0.011139154434204102 |      124         |
# |     ppb                 |       64     |   40.067588806152344  |   42.83238220214844      |   0.011999130249023438 |      124         |
# |     ppb                 |       65     |   39.96639633178711   |   42.714691162109375     |   0.012492895126342773 |      124         |
# |     ppb                 |       66     |   39.96639633178711   |   42.714691162109375     |   0.012421846389770508 |      124         |
# |     ppb                 |       67     |   39.96639633178711   |   42.714691162109375     |   0.010089874267578125 |      124         |
# |     ppb                 |       68     |   39.96639633178711   |   42.714691162109375     |   0.01671004295349121  |      124         |
# |     ppb                 |       69     |   39.96639633178711   |   42.714691162109375     |   0.012579679489135742 |      124         |
# |     ppb                 |       70     |   39.964500427246094  |   42.71920394897461      |   0.01346588134765625  |      126         |
# |     ppb                 |       71     |   39.964500427246094  |   42.71920394897461      |   0.012253999710083008 |      126         |
# |     ppb                 |       72     |   39.964500427246094  |   42.71920394897461      |   0.012419939041137695 |      126         |
# |     ppb                 |       73     |   39.964500427246094  |   42.71920394897461      |   0.012137889862060547 |      126         |
# |     ppb                 |       74     |   39.964500427246094  |   42.71920394897461      |   0.009831905364990234 |      126         |
# |     ppb                 |       75     |   39.964500427246094  |   42.71920394897461      |   0.014032125473022461 |      126         |
# |     ppb                 |       76     |   39.964500427246094  |   42.71920394897461      |   0.012612104415893555 |      126         |
# |     ppb                 |       77     |   39.964500427246094  |   42.71920394897461      |   0.01177978515625     |      126         |
# |     ppb                 |       78     |   39.630714416503906  |   42.3962287902832       |   0.012231826782226562 |      124         |
# |     ppb                 |       79     |   39.630714416503906  |   42.3962287902832       |   0.012138843536376953 |      124         |
# |     ppb                 |       80     |   39.630714416503906  |   42.3962287902832       |   0.010936975479125977 |      124         |
# |     ppb                 |       81     |   39.630714416503906  |   42.3962287902832       |   0.0098419189453125   |      124         |
# |     ppb                 |       82     |   39.630714416503906  |   42.3962287902832       |   0.010710000991821289 |      124         |
# |     ppb                 |       83     |   39.630714416503906  |   42.3962287902832       |   0.014221906661987305 |      124         |
# |     ppb                 |       84     |   39.630714416503906  |   42.3962287902832       |   0.012214899063110352 |      124         |
# |     ppb                 |       85     |   39.630714416503906  |   42.3962287902832       |   0.010497808456420898 |      124         |
# |     ppb                 |       86     |   39.630714416503906  |   42.3962287902832       |   0.013954639434814453 |      124         |
# |     ppb                 |       87     |   39.630714416503906  |   42.3962287902832       |   0.009937047958374023 |      124         |
# |     ppb                 |       88     |   39.630714416503906  |   42.3962287902832       |   0.01022958755493164  |      124         |
# |     ppb                 |       89     |   39.630714416503906  |   42.3962287902832       |   0.00982213020324707  |      124         |
# |     ppb                 |       90     |   39.630714416503906  |   42.3962287902832       |   0.012135982513427734 |      124         |
# |     ppb                 |       91     |   39.630714416503906  |   42.3962287902832       |   0.010360002517700195 |      124         |
# |     ppb                 |       92     |   39.630714416503906  |   42.3962287902832       |   0.011728048324584961 |      124         |
# |     ppb                 |       93     |   39.630714416503906  |   42.3962287902832       |   0.010939836502075195 |      124         |
# |     ppb                 |       94     |   39.630714416503906  |   42.3962287902832       |   0.013522863388061523 |      124         |
# |     ppb                 |       95     |   39.418304443359375  |   42.17953872680664      |   0.01275491714477539  |      124         |
# |     ppb                 |       96     |   39.418304443359375  |   42.17953872680664      |   0.00738978385925293  |      124         |
# |     ppb                 |       97     |   39.418304443359375  |   42.17953872680664      |   0.008477926254272461 |      124         |
# |     ppb                 |       98     |   39.418304443359375  |   42.17953872680664      |   0.01061701774597168  |      124         |
# |     ppb                 |       99     |   39.418304443359375  |   42.17953872680664      |   0.007585763931274414 |      124         |
# |     ppb                 |       100    |   39.418304443359375  |   42.17953872680664      |   0.014243125915527344 |      124         |
# (np.str_('multiply'), np.str_('x56'), np.str_('x481')) + f((np.str_('divide'), np.str_('x522'), np.str_('x372')) - (np.str_('multiply'), np.str_('x331'), np.str_('x335'))) + f((np.str_('multiply'), np.str_('x266'), np.str_('x451')) - (np.str_('multiply'), np.str_('constant__1.0'), np.str_('x308'))) + f((np.str_('divide'), np.str_('x532'), np.str_('x528')) - (np.str_('subtract'), np.str_('constant__1.0'), np.str_('x547'))) + f((np.str_('add'), np.str_('constant_5.0'), np.str_('x582')) - (np.str_('subtract'), np.str_('constant__1.0'), np.str_('x432'))) + f((np.str_('add'), np.str_('x191'), np.str_('x454')) - (np.str_('subtract'), np.str_('constant_2.0'), np.str_('x391'))) + f((np.str_('add'), np.str_('x198'), np.str_('x27')) - (np.str_('divide'), np.str_('x574'), np.str_('x329'))) + f((np.str_('add'), np.str_('x332'), np.str_('x373')) - (np.str_('subtract'), np.str_('x576'), np.str_('constant_5.0'))) + f((np.str_('add'), np.str_('constant_4.0'), np.str_('x281')) - (np.str_('divide'), np.str_('constant_4.0'), np.str_('constant__1.0'))) + f((np.str_('subtract'), np.str_('x392'), np.str_('x282')) - (np.str_('subtract'), np.str_('x375'), np.str_('x273'))) + f((np.str_('divide'), np.str_('x369'), np.str_('x146')) - (np.str_('divide'), np.str_('x409'), np.str_('constant__1.0'))) + f((np.str_('subtract'), np.str_('constant_4.0'), np.str_('x622')) - (np.str_('subtract'), np.str_('x573'), np.str_('x125')))
# 39.848846435546875
